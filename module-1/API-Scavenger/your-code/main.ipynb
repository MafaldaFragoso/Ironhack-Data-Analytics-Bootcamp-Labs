# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
import json
import requests
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
username = 'MafaldaFragoso'
token = 'xxxxx'

response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks', auth=(username,token))
data = pd.DataFrame(response.json())
data.head()
# Out:
#           id                           node_id         name  \
# 0  242350251  MDEwOlJlcG9zaXRvcnkyNDIzNTAyNTE=  dataV2-labs
# 1  241335460  MDEwOlJlcG9zaXRvcnkyNDEzMzU0NjA=  dataV2-labs
# 2  241335029  MDEwOlJlcG9zaXRvcnkyNDEzMzUwMjk=  dataV2-labs
# 3  241334117  MDEwOlJlcG9zaXRvcnkyNDEzMzQxMTc=  dataV2-labs
# 4  241333755  MDEwOlJlcG9zaXRvcnkyNDEzMzM3NTU=  dataV2-labs
#
#                  full_name  private  \
# 0  ta-data-lis/dataV2-labs    False
# 1    pmoreira1/dataV2-labs    False
# 2      mazzoal/dataV2-labs    False
# 3        c-cle/dataV2-labs    False
# 4    ReneRaube/dataV2-labs    False
#
#                                                owner  \
# 0  {'login': 'ta-data-lis', 'id': 54109907, 'node...
# 1  {'login': 'pmoreira1', 'id': 22530149, 'node_i...
# 2  {'login': 'mazzoal', 'id': 60705285, 'node_id'...
# 3  {'login': 'c-cle', 'id': 58886069, 'node_id': ...
# 4  {'login': 'ReneRaube', 'id': 60393329, 'node_i...
#
#                                      html_url  \
# ...

# %%
print(list(data.columns))
# Out:
# ['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license', '
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
language_attribute=[]
for x in data['languages_url']:
    test = requests.get(x, auth=(username,token))
    language_attribute.append(test.json().keys())
print(language_attribute)
# Out:
# [dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'TSQL', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Rich Text Format', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python', 'TSQL']), dict_keys(['Jupyter Notebook', 'HTML', 'Python', 'Rich Text Format']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python', 'TSQL']), dict_keys(['Jupyter Notebook', 'HTML', 'TSQL', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python', 'TSQL']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']), dict_keys(['Jupyter Notebook', 'HTML', 'Python']),
# ...

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
response2 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?since=2019-10-01T00:00:00Z&until=2019-10-31T23:59:59Z', auth=(username,token))
data2 = pd.DataFrame(response2.json())

results2 = response2.json()
flattened_data2 = json_normalize(results2)

flattened_data2.head()
# Out:
#                                         sha  \
# 0  37e0b0681ff829d1c9f4a542631229efe7d577ff
# 1  d9da31ef64900ad297d5d811d4f9c45e66fa8e8f
# 2  957cd5b2250076833fce0f363b42b4a77660e4eb
# 3  48503eb5aff61da2e7c1fdd55f3f7e407360ad29
# 4  a0cc914495a7e137e298cd6f5d47948b5cf64807
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjEzNjQxMTcwOjM3ZTBiMDY4MWZmODI5ZD...
# 1  MDY6Q29tbWl0MjEzNjQxMTcwOmQ5ZGEzMWVmNjQ5MDBhZD...
# 2  MDY6Q29tbWl0MjEzNjQxMTcwOjk1N2NkNWIyMjUwMDc2OD...
# 3  MDY6Q29tbWl0MjEzNjQxMTcwOjQ4NTAzZWI1YWZmNjFkYT...
# 4  MDY6Q29tbWl0MjEzNjQxMTcwOmEwY2M5MTQ0OTVhN2UxMz...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
len(flattened_data2)
# Out:
# 30

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
